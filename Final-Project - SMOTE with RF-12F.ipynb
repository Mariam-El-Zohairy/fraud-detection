# %%
#Imp Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Open data
CC=pd.read_csv("creditcard.csv")
#Data describtion
CC.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
#Data describtion
CC.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
#Data describtion
CC.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.165980e-15  3.416908e-16 -1.373150e-15  2.086869e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.490107e-15 -5.556467e-16  1.177556e-16 -2.406455e-15
# ...

# %%
#Data describtion
print (CC.shape)
print (CC.size)
print (CC.count())
print (CC["Class"].value_counts())
# Out:
# (284807, 31)
# 8829017
# Time      284807
# V1        284807
# V2        284807
# V3        284807
# V4        284807
# V5        284807
# V6        284807
# V7        284807
# V8        284807
# V9        284807
# V10       284807
# V11       284807
# V12       284807
# V13       284807
# V14       284807
# V15       284807
# V16       284807
# V17       284807
# V18       284807
# V19       284807
# V20       284807
# V21       284807
# V22       284807
# V23       284807
# V24       284807
# V25       284807
# V26       284807
# V27       284807
# V28       284807
# Amount    284807
# Class     284807
# dtype: int64
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
#Data Visualization
plt.title('CC "Class" Plot')
sns.countplot(x='Class',data=CC)

# %%
#Data Visualization
sns.lmplot(x='Time',y='Amount',data=CC,fit_reg=False,hue='Class',height=7,aspect=2)
plt.title('CC Amount-Time Plot')
# Out:
# Text(0.5, 1, 'CC Amount-Time Plot')

# %%
#Data Visualization
plt.figure(figsize = (10,10))
plt.title('CC Correlation Plot')
sns.heatmap(CC.corr(),linewidths=0.02)

# %%
#Data Visualization
C= CC.columns.values
i = 0
C0 = CC.loc[CC['Class'] == 0]
C1 = CC.loc[CC['Class'] == 1]

sns.set_style('whitegrid')
plt.figure()
fig, ax = plt.subplots(8,4,figsize=(16,28))

for feature in C:
    i += 1
    plt.subplot(8,4,i)
    sns.kdeplot(C0[feature], bw=0.5,label="Class = 0")
    sns.kdeplot(C1[feature], bw=0.5,label="Class = 1")
    plt.xlabel(feature, fontsize=9)
    locs, labels = plt.xticks()
    plt.tick_params(axis='both', which='major', labelsize=9)
plt.show()
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\Anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
#Features scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
CC["S_Amount"]=  sc.fit_transform(CC.iloc[:,29].values.reshape(-1,1))

# %%
CC.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class', 'S_Amount'],
#       dtype='object')

# %%
#Dependent and independent variables
Features_CC= CC[['V1', 'V2', 'V3', 'V4', 'V9', 'V10','V11', 'V12','V14','V18', 'V19', 'S_Amount']]
Labels_CC= CC[['Class']]

# %%
#Train and test split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(Features_CC, Labels_CC, test_size = 0.25, random_state = 0)

# %%
#Train and test split
print (x_train.shape)
print (y_train.shape)
print (x_test.shape)
print (y_test.shape)
# Out:
# (213605, 12)
# (213605, 1)
# (71202, 12)
# (71202, 1)

# %%
#Oversampling SMOTE
from imblearn.over_sampling import SMOTE
OS=SMOTE(random_state=0)
OS_x_train,OS_y_train=OS.fit_sample(x_train,y_train)

print (OS_y_train["Class"].value_counts())
print (OS_x_train.shape)
# Out:
# 1    213233
# 0    213233
# Name: Class, dtype: int64
# (426466, 12)

# %%
#Balanced class visualization
plt.title('OS_y_train "Class" Plot')
sns.countplot(x='Class',data=OS_y_train)

# %%
#Array formation
Nx=np.asarray(OS_x_train)
Ny=np.asarray(OS_y_train["Class"])

# %%
#Training RF model
from sklearn.ensemble import RandomForestClassifier
RF=RandomForestClassifier().fit(Nx,Ny)

# %%
#RF model
RF
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
#Saving model
import pickle
filename = 'Finalized_model_SMOTE_RF_12F'
with open(filename,'wb') as file:
    pickle.dump(RF, file)

# %%
#Loading model
with open(filename, 'rb') as file:  
    Pickled_LR_Model = pickle.load(file)
    y_pred2 = Pickled_LR_Model.predict(x_test)
    print(classification_report(y_test,y_pred2))
    

Pickled_LR_Model
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71082
#            1       0.89      0.84      0.86       120
#
#     accuracy                           1.00     71202
#    macro avg       0.94      0.92      0.93     71202
# weighted avg       1.00      1.00      1.00     71202
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
#Testing RF model
y_pred=RF.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
#Classification report
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71082
#            1       0.89      0.84      0.86       120
#
#     accuracy                           1.00     71202
#    macro avg       0.94      0.92      0.93     71202
# weighted avg       1.00      1.00      1.00     71202

# %%
#Accuracy score
from sklearn.metrics import accuracy_score
print("Radom Forest Classifier accuracy is : ",accuracy_score(y_pred,y_test)*100,"%")
# Out:
# Radom Forest Classifier accuracy is :  99.95505744220668 %

# %%
#Confusion matrix
from sklearn.metrics import confusion_matrix,f1_score
cm = confusion_matrix(y_test, y_pred)
from mlxtend.plotting import plot_confusion_matrix
plot_confusion_matrix(cm)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1debd4608c8>)

# %%
#F1 score
f1_score(y_test,y_pred)
# Out:
# 0.8632478632478633

# %%
#Grid search
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
parameters = {'n_estimators':[1,5,10,100],'max_depth':[3,5,10,None],'criterion':['gini','entropy'],}
gsearch = GridSearchCV(RF, parameters, cv=5)
gsearch.fit(Nx, Ny)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=None,
#                                               oob_score=False,
# ...

# %%
#Best grid search parameters
model = gsearch.best_estimator_
print("Best score: ",gsearch.best_score_," acheived by these parameters ",model)
# Out:
# Best score:  0.9888455338899076  acheived by these parameters  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=10, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
